# %%
from n2v.models import N2VConfig, N2V
import numpy as np
from csbdeep.utils import plot_history
from n2v.utils.n2v_utils import manipulate_val_data, autocorrelation
from n2v.internals.N2V_DataGenerator import N2V_DataGenerator
from matplotlib import pyplot as plt
import urllib
import os
import zipfile
import glob
import os.path
import zipfile
from tifffile import imread
from tifffile import imshow
from tifffile import imwrite
import pathlib
from csbdeep.io import save_tiff_imagej_compatible
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tensorflow as tf
import keras
import cv2
# Out:
# Using Theano backend.
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# C:\Users\17605\ImJoyApp\envs\n2v\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
print(tf.__version__)
print(keras.__version__)

tf.test.is_gpu_available(
    cuda_only=False, min_cuda_compute_capability=None
)
# Out:
# 2.4.1
# 2.3.1
# WARNING:tensorflow:From <ipython-input-5-c42fad3dea0f>:5: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
datagen = N2V_DataGenerator()

# %%
folder = "F:/Jesse/cKO/cKO_PIV_less/Nuclei/317/"

imgs = datagen.load_imgs_from_directory(directory = folder,filter = '*.tif', dims='ZYX')

print(imgs[0].shape)
print(imgs[1].shape)
# Out:
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# (1, 200, 276, 576, 1)
# (1, 200, 300, 576, 1)

# %%
# Let's look at a maximum projection of the volume.
# We have to remove the added extra dimensions to display it.
plt.figure(figsize=(32,16))
plt.imshow(np.max(imgs[0][0,...,0],axis=0), 
           cmap='magma',
           vmin=np.percentile(imgs[0],0.1),
           vmax=np.percentile(imgs[0],99.9)
          )
plt.show()

# %%
# Here we extract patches for training and validation.
patch_shape = (16, 16, 16)
patches = datagen.generate_patches_from_list(imgs[0:1], shape=patch_shape)
# Out:
# Generated patches: (124416, 16, 32, 32, 1)

# %%
X = patches[:int(len(patches)-(len(patches)/10)),:]
X_val = patches[int(len(patches)-(len(patches)/10)):,:]

print(np.shape(X_val))
print(np.shape(X))
# Out:
# (12442, 16, 32, 32, 1)
# (111974, 16, 32, 32, 1)

# %%
patch_shape = (32,32)
patches = datagen.generate_patches_from_list(imgs, shape=patch_shape)
X = patches[:int(len(patches)-(len(patches)/5)),:]
X_val = patches[int(len(patches)-(len(patches)/5)):,:]

# %%
# Let's look at two patches.
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.imshow(X[0,8,...,0],cmap='magma')
plt.title('Training Patch');
plt.subplot(1,2,2)
plt.imshow(X_val[0,8,...,0],cmap='magma')
plt.title('Validation Patch');

# %%
# You can increase "train_steps_per_epoch" to get even better results at the price of longer computation. 
config = N2VConfig(X, unet_kern_size=3, 
                   train_steps_per_epoch=int(X.shape[0]/128),train_epochs=200, train_loss='mse', batch_norm=True, 
                   train_batch_size=30, n2v_perc_pix=0.198, n2v_patch_shape=(16, 16, 16), 
                   n2v_manipulator='uniform_withCP', n2v_neighborhood_radius=5)

# Let's look at the parameters stored in the config-object.
vars(config)
# Out:
# {'means': ['2494.7876'],
#  'stds': ['6966.227'],
#  'n_dim': 3,
#  'axes': 'ZYXC',
#  'n_channel_in': 1,
#  'n_channel_out': 1,
#  'unet_residual': False,
#  'unet_n_depth': 2,
#  'unet_kern_size': 3,
#  'unet_n_first': 32,
#  'unet_last_activation': 'linear',
#  'unet_input_shape': (None, None, None, 1),
#  'train_loss': 'mse',
#  'train_epochs': 200,
#  'train_steps_per_epoch': 874,
#  'train_learning_rate': 0.0004,
#  'train_batch_size': 30,
#  'train_tensorboard': True,
#  'train_checkpoint': 'weights_best.h5',
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10},
#  'batch_norm': True,
#  'n2v_perc_pix': 0.198,
#  'n2v_patch_shape': (16, 16, 16),
#  'n2v_manipulator': 'uniform_withCP',
#  'n2v_neighborhood_radius': 5,
#  'single_net_per_channel': True,
#  'structN2Vmask': None,
#  'probabilistic': False}

# %%
# a name used to identify the model
model_name = '2022_04_21_n2v_317cko'
# the base directory in which our model will live
basedir = 'models'
# We are now creating our network model.
model = N2V(config=config, name=model_name, basedir=basedir)
# model.config.axes='YXC'
# # We load the data we want to process.
# input_train = imread('data/flower.tif')[...,None]

# # Here we process the data.
# # The parameter 'n_tiles' can be used if images are to big for the GPU memory.
# # If we do not provide the n_tiles' parameter the system will automatically try to find an appropriate tiling.
# # This can take longer.
# pred_train = []
# for _x in input_train[:2]:
#     _yp = model.predict(_x, axes='YXC', n_tiles=(1,1,1))
#     pred_train.append(_yp)
# pred_train = np.array(pred_train)

# # We load and process the data we previously used for validation.
# # input_val = imread('data/validation.tif')
# # pred_val = model.predict(input_val, axes='TYX')
# Out:
# C:\Users\17605\ImJoyApp\envs\n2v\lib\site-packages\n2v\models\n2v_standard.py:416: UserWarning: output path for model already exists, files may be overwritten: C:\Users\17605\Code\n2v\examples\3D\models\2022_04_21_n2v_317cko
#   'output path for model already exists, files may be overwritten: %s' % str(self.logdir.resolve()))

# %%
history = model.train(X, X_val)
# Out:
# 8 blind-spots will be generated per training patch of size (16, 16, 16).
# Preparing validation data: 100%|███████████████████████████████████████████████| 12442/12442 [00:02<00:00, 5761.56it/s]
# Epoch 1/200
# 874/874 [==============================] - 78s 86ms/step - loss: 0.8945 - n2v_mse: 0.8945 - n2v_abs: 0.2497 - val_loss: 0.1345 - val_n2v_mse: 0.1345 - val_n2v_abs: 0.1116
# Epoch 2/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.2393 - n2v_mse: 0.2393 - n2v_abs: 0.1389 - val_loss: 0.1187 - val_n2v_mse: 0.1187 - val_n2v_abs: 0.0969
# Epoch 3/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.2422 - n2v_mse: 0.2422 - n2v_abs: 0.1468 - val_loss: 0.0719 - val_n2v_mse: 0.0719 - val_n2v_abs: 0.0878
# Epoch 4/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.1875 - n2v_mse: 0.1875 - n2v_abs: 0.1317 - val_loss: 0.3346 - val_n2v_mse: 0.3346 - val_n2v_abs: 0.2003
# Epoch 5/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.2382 - n2v_mse: 0.2382 - n2v_abs: 0.1519 - val_loss: 0.9137 - val_n2v_mse: 0.9134 - val_n2v_abs: 0.2487
# Epoch 6/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.1603 - n2v_mse: 0.1603 - n2v_abs: 0.1332 - val_loss: 0.1667 - val_n2v_mse: 0.1668 - val_n2v_abs: 0.1109
# Epoch 7/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.1256 - n2v_mse: 0.1256 - n2v_abs: 0.1205 - val_loss: 0.0916 - val_n2v_mse: 0.0917 - val_n2v_abs: 0.0917
# Epoch 8/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.1154 - n2v_mse: 0.1154 - n2v_abs: 0.1257 - val_loss: 0.0206 - val_n2v_mse: 0.0206 - val_n2v_abs: 0.0622
# Epoch 9/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0752 - n2v_mse: 0.0752 - n2v_abs: 0.1070 - val_loss: 0.0237 - val_n2v_mse: 0.0236 - val_n2v_abs: 0.0603
# Epoch 10/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0828 - n2v_mse: 0.0828 - n2v_abs: 0.1009 - val_loss: 0.0948 - val_n2v_mse: 0.0948 - val_n2v_abs: 0.0833
# Epoch 11/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0829 - n2v_mse: 0.0829 - n2v_abs: 0.0983 - val_loss: 0.0247 - val_n2v_mse: 0.0247 - val_n2v_abs: 0.0629
# Epoch 12/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0837 - n2v_mse: 0.0837 - n2v_abs: 0.0939 - val_loss: 0.0504 - val_n2v_mse: 0.0504 - val_n2v_abs: 0.0630
# Epoch 13/200
# 874/874 [==============================] - 74s 84ms/step - loss: 0.0637 - n2v_mse: 0.0637 - n2v_abs: 0.0786 - val_loss: 0.1373 - val_n2v_mse: 0.1373 - val_n2v_abs: 0.1031
# Epoch 14/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0680 - n2v_mse: 0.0680 - n2v_abs: 0.0834 - val_loss: 0.0198 - val_n2v_mse: 0.0198 - val_n2v_abs: 0.0517
# Epoch 15/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.0673 - n2v_mse: 0.0673 - n2v_abs: 0.0908 - val_loss: 0.0347 - val_n2v_mse: 0.0347 - val_n2v_abs: 0.0596
# Epoch 16/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0822 - n2v_mse: 0.0822 - n2v_abs: 0.0857 - val_loss: 0.0437 - val_n2v_mse: 0.0437 - val_n2v_abs: 0.0634
# Epoch 17/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0523 - n2v_mse: 0.0523 - n2v_abs: 0.0741 - val_loss: 0.0444 - val_n2v_mse: 0.0444 - val_n2v_abs: 0.0859
# Epoch 18/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0797 - n2v_mse: 0.0797 - n2v_abs: 0.0851 - val_loss: 0.0361 - val_n2v_mse: 0.0361 - val_n2v_abs: 0.0694
# Epoch 19/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0553 - n2v_mse: 0.0553 - n2v_abs: 0.0755 - val_loss: 0.0208 - val_n2v_mse: 0.0208 - val_n2v_abs: 0.0521
# Epoch 20/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0549 - n2v_mse: 0.0549 - n2v_abs: 0.0745 - val_loss: 0.0223 - val_n2v_mse: 0.0223 - val_n2v_abs: 0.0528
# Epoch 21/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0712 - n2v_mse: 0.0712 - n2v_abs: 0.0783 - val_loss: 0.0237 - val_n2v_mse: 0.0236 - val_n2v_abs: 0.0593
# Epoch 22/200
# 874/874 [==============================] - 70s 81ms/step - loss: 0.0370 - n2v_mse: 0.0370 - n2v_abs: 0.0630 - val_loss: 0.0211 - val_n2v_mse: 0.0211 - val_n2v_abs: 0.0495
# Epoch 23/200
# 874/874 [==============================] - 70s 81ms/step - loss: 0.0409 - n2v_mse: 0.0409 - n2v_abs: 0.0668 - val_loss: 0.0162 - val_n2v_mse: 0.0162 - val_n2v_abs: 0.0412
# Epoch 24/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0401 - n2v_mse: 0.0401 - n2v_abs: 0.0632 - val_loss: 0.0186 - val_n2v_mse: 0.0186 - val_n2v_abs: 0.0422
# Epoch 25/200
# 874/874 [==============================] - 77s 88ms/step - loss: 0.0457 - n2v_mse: 0.0457 - n2v_abs: 0.0681 - val_loss: 0.0287 - val_n2v_mse: 0.0287 - val_n2v_abs: 0.0654
# Epoch 26/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0332 - n2v_mse: 0.0332 - n2v_abs: 0.0599 - val_loss: 0.0831 - val_n2v_mse: 0.0831 - val_n2v_abs: 0.0799
# Epoch 27/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0468 - n2v_mse: 0.0468 - n2v_abs: 0.0664 - val_loss: 0.0327 - val_n2v_mse: 0.0327 - val_n2v_abs: 0.0677
# Epoch 28/200
# 874/874 [==============================] - 77s 88ms/step - loss: 0.0388 - n2v_mse: 0.0388 - n2v_abs: 0.0615 - val_loss: 0.0301 - val_n2v_mse: 0.0300 - val_n2v_abs: 0.0447
# Epoch 29/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0416 - n2v_mse: 0.0416 - n2v_abs: 0.0643 - val_loss: 0.0242 - val_n2v_mse: 0.0242 - val_n2v_abs: 0.0679
# Epoch 30/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0394 - n2v_mse: 0.0394 - n2v_abs: 0.0649 - val_loss: 0.1272 - val_n2v_mse: 0.1272 - val_n2v_abs: 0.0988
# Epoch 31/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0502 - n2v_mse: 0.0502 - n2v_abs: 0.0714 - val_loss: 0.0728 - val_n2v_mse: 0.0728 - val_n2v_abs: 0.0897
# Epoch 32/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0282 - n2v_mse: 0.0282 - n2v_abs: 0.0597 - val_loss: 0.0431 - val_n2v_mse: 0.0431 - val_n2v_abs: 0.0634
# Epoch 33/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0393 - n2v_mse: 0.0393 - n2v_abs: 0.0617 - val_loss: 0.0236 - val_n2v_mse: 0.0236 - val_n2v_abs: 0.0693
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 34/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0186 - n2v_mse: 0.0186 - n2v_abs: 0.0483 - val_loss: 0.0411 - val_n2v_mse: 0.0411 - val_n2v_abs: 0.0670
# Epoch 35/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0285 - n2v_mse: 0.0285 - n2v_abs: 0.0513 - val_loss: 0.0606 - val_n2v_mse: 0.0606 - val_n2v_abs: 0.0742
# Epoch 36/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0240 - n2v_mse: 0.0240 - n2v_abs: 0.0510 - val_loss: 0.0268 - val_n2v_mse: 0.0268 - val_n2v_abs: 0.0628
# Epoch 37/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0187 - n2v_mse: 0.0187 - n2v_abs: 0.0478 - val_loss: 0.0221 - val_n2v_mse: 0.0221 - val_n2v_abs: 0.0644
# Epoch 38/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0214 - n2v_mse: 0.0214 - n2v_abs: 0.0490 - val_loss: 0.0231 - val_n2v_mse: 0.0231 - val_n2v_abs: 0.0483
# Epoch 39/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0207 - n2v_mse: 0.0207 - n2v_abs: 0.0501 - val_loss: 0.0151 - val_n2v_mse: 0.0151 - val_n2v_abs: 0.0505
# Epoch 40/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0177 - n2v_mse: 0.0177 - n2v_abs: 0.0459 - val_loss: 0.0476 - val_n2v_mse: 0.0475 - val_n2v_abs: 0.0929
# Epoch 41/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0202 - n2v_mse: 0.0202 - n2v_abs: 0.0479 - val_loss: 0.0459 - val_n2v_mse: 0.0459 - val_n2v_abs: 0.0865
# Epoch 42/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0140 - n2v_mse: 0.0140 - n2v_abs: 0.0435 - val_loss: 0.0322 - val_n2v_mse: 0.0322 - val_n2v_abs: 0.0608
# Epoch 43/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0255 - n2v_mse: 0.0255 - n2v_abs: 0.0496 - val_loss: 0.0472 - val_n2v_mse: 0.0471 - val_n2v_abs: 0.0770
# Epoch 44/200
# 874/874 [==============================] - 69s 79ms/step - loss: 0.0218 - n2v_mse: 0.0218 - n2v_abs: 0.0489 - val_loss: 0.0383 - val_n2v_mse: 0.0383 - val_n2v_abs: 0.0953
# Epoch 45/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0143 - n2v_mse: 0.0143 - n2v_abs: 0.0450 - val_loss: 0.0317 - val_n2v_mse: 0.0317 - val_n2v_abs: 0.0703
# Epoch 46/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0225 - n2v_mse: 0.0225 - n2v_abs: 0.0497 - val_loss: 0.0335 - val_n2v_mse: 0.0335 - val_n2v_abs: 0.0784
# Epoch 47/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0121 - n2v_mse: 0.0121 - n2v_abs: 0.0429 - val_loss: 0.0305 - val_n2v_mse: 0.0305 - val_n2v_abs: 0.0691
# Epoch 48/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0152 - n2v_mse: 0.0152 - n2v_abs: 0.0440 - val_loss: 0.0324 - val_n2v_mse: 0.0324 - val_n2v_abs: 0.0666
# Epoch 49/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0152 - n2v_mse: 0.0152 - n2v_abs: 0.0458 - val_loss: 0.0320 - val_n2v_mse: 0.0320 - val_n2v_abs: 0.0619
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 50/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0138 - n2v_mse: 0.0138 - n2v_abs: 0.0463 - val_loss: 0.0402 - val_n2v_mse: 0.0402 - val_n2v_abs: 0.0616
# Epoch 51/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0083 - n2v_mse: 0.0083 - n2v_abs: 0.0367 - val_loss: 0.0580 - val_n2v_mse: 0.0580 - val_n2v_abs: 0.0787
# Epoch 52/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0123 - n2v_mse: 0.0123 - n2v_abs: 0.0432 - val_loss: 0.0318 - val_n2v_mse: 0.0318 - val_n2v_abs: 0.0565
# Epoch 53/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0084 - n2v_mse: 0.0084 - n2v_abs: 0.0367 - val_loss: 0.0569 - val_n2v_mse: 0.0569 - val_n2v_abs: 0.0790
# Epoch 54/200
# 874/874 [==============================] - 77s 88ms/step - loss: 0.0126 - n2v_mse: 0.0126 - n2v_abs: 0.0397 - val_loss: 0.0641 - val_n2v_mse: 0.0641 - val_n2v_abs: 0.0817
# Epoch 55/200
# 874/874 [==============================] - 77s 88ms/step - loss: 0.0132 - n2v_mse: 0.0132 - n2v_abs: 0.0397 - val_loss: 0.0527 - val_n2v_mse: 0.0527 - val_n2v_abs: 0.0719
# Epoch 56/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0113 - n2v_mse: 0.0113 - n2v_abs: 0.0378 - val_loss: 0.0487 - val_n2v_mse: 0.0487 - val_n2v_abs: 0.0746
# Epoch 57/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0123 - n2v_mse: 0.0123 - n2v_abs: 0.0405 - val_loss: 0.0303 - val_n2v_mse: 0.0303 - val_n2v_abs: 0.0553
# Epoch 58/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0083 - n2v_mse: 0.0083 - n2v_abs: 0.0351 - val_loss: 0.0621 - val_n2v_mse: 0.0621 - val_n2v_abs: 0.0778
# Epoch 59/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0108 - n2v_mse: 0.0108 - n2v_abs: 0.0390 - val_loss: 0.0455 - val_n2v_mse: 0.0455 - val_n2v_abs: 0.0683
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 60/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0069 - n2v_mse: 0.0069 - n2v_abs: 0.0340 - val_loss: 0.0658 - val_n2v_mse: 0.0658 - val_n2v_abs: 0.0780
# Epoch 61/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0067 - n2v_mse: 0.0067 - n2v_abs: 0.0335 - val_loss: 0.0541 - val_n2v_mse: 0.0541 - val_n2v_abs: 0.0751
# Epoch 62/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.0078 - n2v_mse: 0.0078 - n2v_abs: 0.0349 - val_loss: 0.0354 - val_n2v_mse: 0.0354 - val_n2v_abs: 0.0617
# Epoch 63/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0078 - n2v_mse: 0.0078 - n2v_abs: 0.0357 - val_loss: 0.0526 - val_n2v_mse: 0.0526 - val_n2v_abs: 0.0729
# Epoch 64/200
# 874/874 [==============================] - 71s 82ms/step - loss: 0.0063 - n2v_mse: 0.0063 - n2v_abs: 0.0329 - val_loss: 0.0530 - val_n2v_mse: 0.0530 - val_n2v_abs: 0.0723
# Epoch 65/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0076 - n2v_mse: 0.0076 - n2v_abs: 0.0339 - val_loss: 0.0465 - val_n2v_mse: 0.0465 - val_n2v_abs: 0.0684
# Epoch 66/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0059 - n2v_mse: 0.0059 - n2v_abs: 0.0328 - val_loss: 0.0442 - val_n2v_mse: 0.0442 - val_n2v_abs: 0.0682
# Epoch 67/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0057 - n2v_mse: 0.0057 - n2v_abs: 0.0324 - val_loss: 0.0420 - val_n2v_mse: 0.0420 - val_n2v_abs: 0.0633
# Epoch 68/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.0068 - n2v_mse: 0.0068 - n2v_abs: 0.0349 - val_loss: 0.0432 - val_n2v_mse: 0.0432 - val_n2v_abs: 0.0635
# Epoch 69/200
# 874/874 [==============================] - 74s 84ms/step - loss: 0.0066 - n2v_mse: 0.0066 - n2v_abs: 0.0343 - val_loss: 0.0638 - val_n2v_mse: 0.0638 - val_n2v_abs: 0.0780
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 70/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0087 - n2v_mse: 0.0087 - n2v_abs: 0.0356 - val_loss: 0.0370 - val_n2v_mse: 0.0370 - val_n2v_abs: 0.0596
# Epoch 71/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0078 - n2v_mse: 0.0078 - n2v_abs: 0.0364 - val_loss: 0.0497 - val_n2v_mse: 0.0497 - val_n2v_abs: 0.0732
# Epoch 72/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0068 - n2v_mse: 0.0068 - n2v_abs: 0.0329 - val_loss: 0.0372 - val_n2v_mse: 0.0372 - val_n2v_abs: 0.0647
# Epoch 73/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.0080 - n2v_mse: 0.0080 - n2v_abs: 0.0338 - val_loss: 0.0431 - val_n2v_mse: 0.0431 - val_n2v_abs: 0.0667
# Epoch 74/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0077 - n2v_mse: 0.0077 - n2v_abs: 0.0337 - val_loss: 0.0490 - val_n2v_mse: 0.0490 - val_n2v_abs: 0.0708
# Epoch 75/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0064 - n2v_mse: 0.0064 - n2v_abs: 0.0323 - val_loss: 0.0552 - val_n2v_mse: 0.0552 - val_n2v_abs: 0.0733
# Epoch 76/200
# 874/874 [==============================] - 71s 82ms/step - loss: 0.0056 - n2v_mse: 0.0056 - n2v_abs: 0.0323 - val_loss: 0.0553 - val_n2v_mse: 0.0553 - val_n2v_abs: 0.0702
# Epoch 77/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0054 - n2v_mse: 0.0054 - n2v_abs: 0.0318 - val_loss: 0.0495 - val_n2v_mse: 0.0495 - val_n2v_abs: 0.0714
# Epoch 78/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0070 - n2v_mse: 0.0070 - n2v_abs: 0.0327 - val_loss: 0.0391 - val_n2v_mse: 0.0391 - val_n2v_abs: 0.0623
# Epoch 79/200
# 874/874 [==============================] - 69s 79ms/step - loss: 0.0067 - n2v_mse: 0.0067 - n2v_abs: 0.0321 - val_loss: 0.0466 - val_n2v_mse: 0.0466 - val_n2v_abs: 0.0700
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 80/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0103 - n2v_mse: 0.0103 - n2v_abs: 0.0338 - val_loss: 0.0472 - val_n2v_mse: 0.0472 - val_n2v_abs: 0.0686
# Epoch 81/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0052 - n2v_mse: 0.0052 - n2v_abs: 0.0316 - val_loss: 0.0669 - val_n2v_mse: 0.0669 - val_n2v_abs: 0.0838
# Epoch 82/200
# 874/874 [==============================] - 71s 82ms/step - loss: 0.0077 - n2v_mse: 0.0077 - n2v_abs: 0.0335 - val_loss: 0.0366 - val_n2v_mse: 0.0366 - val_n2v_abs: 0.0613
# Epoch 83/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.0064 - n2v_mse: 0.0064 - n2v_abs: 0.0329 - val_loss: 0.0548 - val_n2v_mse: 0.0548 - val_n2v_abs: 0.0739
# Epoch 84/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0085 - n2v_mse: 0.0085 - n2v_abs: 0.0324 - val_loss: 0.0446 - val_n2v_mse: 0.0446 - val_n2v_abs: 0.0674
# Epoch 85/200
# 874/874 [==============================] - 74s 84ms/step - loss: 0.0051 - n2v_mse: 0.0051 - n2v_abs: 0.0313 - val_loss: 0.0614 - val_n2v_mse: 0.0614 - val_n2v_abs: 0.0801
# Epoch 86/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0063 - n2v_mse: 0.0063 - n2v_abs: 0.0313 - val_loss: 0.0416 - val_n2v_mse: 0.0416 - val_n2v_abs: 0.0667
# Epoch 87/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0064 - n2v_mse: 0.0064 - n2v_abs: 0.0323 - val_loss: 0.0499 - val_n2v_mse: 0.0499 - val_n2v_abs: 0.0709
# Epoch 88/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.0059 - n2v_mse: 0.0059 - n2v_abs: 0.0318 - val_loss: 0.0382 - val_n2v_mse: 0.0382 - val_n2v_abs: 0.0638
# Epoch 89/200
# 874/874 [==============================] - 74s 84ms/step - loss: 0.0060 - n2v_mse: 0.0060 - n2v_abs: 0.0320 - val_loss: 0.0602 - val_n2v_mse: 0.0601 - val_n2v_abs: 0.0775
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 90/200
# 874/874 [==============================] - 76s 86ms/step - loss: 0.0047 - n2v_mse: 0.0047 - n2v_abs: 0.0307 - val_loss: 0.0451 - val_n2v_mse: 0.0451 - val_n2v_abs: 0.0668
# Epoch 91/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0056 - n2v_mse: 0.0056 - n2v_abs: 0.0324 - val_loss: 0.0459 - val_n2v_mse: 0.0459 - val_n2v_abs: 0.0686
# Epoch 92/200
# 874/874 [==============================] - 74s 84ms/step - loss: 0.0052 - n2v_mse: 0.0052 - n2v_abs: 0.0305 - val_loss: 0.0790 - val_n2v_mse: 0.0790 - val_n2v_abs: 0.0889
# Epoch 93/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.0064 - n2v_mse: 0.0064 - n2v_abs: 0.0313 - val_loss: 0.0630 - val_n2v_mse: 0.0630 - val_n2v_abs: 0.0792
# Epoch 94/200
# 874/874 [==============================] - 76s 87ms/step - loss: 0.0068 - n2v_mse: 0.0068 - n2v_abs: 0.0319 - val_loss: 0.0484 - val_n2v_mse: 0.0484 - val_n2v_abs: 0.0691
# Epoch 95/200
# 874/874 [==============================] - 75s 86ms/step - loss: 0.0093 - n2v_mse: 0.0093 - n2v_abs: 0.0322 - val_loss: 0.0546 - val_n2v_mse: 0.0546 - val_n2v_abs: 0.0719
# Epoch 96/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0070 - n2v_mse: 0.0070 - n2v_abs: 0.0330 - val_loss: 0.0663 - val_n2v_mse: 0.0663 - val_n2v_abs: 0.0812
# Epoch 97/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0062 - n2v_mse: 0.0062 - n2v_abs: 0.0312 - val_loss: 0.0380 - val_n2v_mse: 0.0380 - val_n2v_abs: 0.0605
# Epoch 98/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0055 - n2v_mse: 0.0055 - n2v_abs: 0.0315 - val_loss: 0.0486 - val_n2v_mse: 0.0486 - val_n2v_abs: 0.0685
# Epoch 99/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0054 - n2v_mse: 0.0054 - n2v_abs: 0.0317 - val_loss: 0.0340 - val_n2v_mse: 0.0340 - val_n2v_abs: 0.0574
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 100/200
# 874/874 [==============================] - 74s 84ms/step - loss: 0.0077 - n2v_mse: 0.0077 - n2v_abs: 0.0310 - val_loss: 0.0619 - val_n2v_mse: 0.0619 - val_n2v_abs: 0.0780
# Epoch 101/200
# 874/874 [==============================] - 75s 85ms/step - loss: 0.0052 - n2v_mse: 0.0052 - n2v_abs: 0.0312 - val_loss: 0.0515 - val_n2v_mse: 0.0515 - val_n2v_abs: 0.0709
# Epoch 102/200
# 874/874 [==============================] - 74s 84ms/step - loss: 0.0066 - n2v_mse: 0.0066 - n2v_abs: 0.0321 - val_loss: 0.0627 - val_n2v_mse: 0.0627 - val_n2v_abs: 0.0782
# Epoch 103/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0054 - n2v_mse: 0.0054 - n2v_abs: 0.0308 - val_loss: 0.0447 - val_n2v_mse: 0.0447 - val_n2v_abs: 0.0666
# Epoch 104/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0094 - n2v_mse: 0.0094 - n2v_abs: 0.0327 - val_loss: 0.0463 - val_n2v_mse: 0.0463 - val_n2v_abs: 0.0677
# Epoch 105/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0055 - n2v_mse: 0.0055 - n2v_abs: 0.0308 - val_loss: 0.0499 - val_n2v_mse: 0.0499 - val_n2v_abs: 0.0709
# Epoch 106/200
# 874/874 [==============================] - 70s 81ms/step - loss: 0.0059 - n2v_mse: 0.0059 - n2v_abs: 0.0302 - val_loss: 0.0429 - val_n2v_mse: 0.0429 - val_n2v_abs: 0.0650
# Epoch 107/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0058 - n2v_mse: 0.0058 - n2v_abs: 0.0301 - val_loss: 0.0396 - val_n2v_mse: 0.0396 - val_n2v_abs: 0.0641
# Epoch 108/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0048 - n2v_mse: 0.0048 - n2v_abs: 0.0301 - val_loss: 0.0363 - val_n2v_mse: 0.0363 - val_n2v_abs: 0.0601
# Epoch 109/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0045 - n2v_mse: 0.0045 - n2v_abs: 0.0298 - val_loss: 0.0401 - val_n2v_mse: 0.0401 - val_n2v_abs: 0.0641
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 110/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0079 - n2v_mse: 0.0079 - n2v_abs: 0.0333 - val_loss: 0.0628 - val_n2v_mse: 0.0628 - val_n2v_abs: 0.0781
# Epoch 111/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0056 - n2v_mse: 0.0056 - n2v_abs: 0.0306 - val_loss: 0.0521 - val_n2v_mse: 0.0521 - val_n2v_abs: 0.0714
# Epoch 112/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0052 - n2v_mse: 0.0052 - n2v_abs: 0.0298 - val_loss: 0.0476 - val_n2v_mse: 0.0476 - val_n2v_abs: 0.0691
# Epoch 113/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0069 - n2v_mse: 0.0069 - n2v_abs: 0.0316 - val_loss: 0.0658 - val_n2v_mse: 0.0658 - val_n2v_abs: 0.0789
# Epoch 114/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0048 - n2v_mse: 0.0048 - n2v_abs: 0.0299 - val_loss: 0.0486 - val_n2v_mse: 0.0486 - val_n2v_abs: 0.0701
# Epoch 115/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0061 - n2v_mse: 0.0061 - n2v_abs: 0.0325 - val_loss: 0.0401 - val_n2v_mse: 0.0401 - val_n2v_abs: 0.0634
# Epoch 116/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0066 - n2v_mse: 0.0066 - n2v_abs: 0.0320 - val_loss: 0.0520 - val_n2v_mse: 0.0520 - val_n2v_abs: 0.0710
# Epoch 117/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0038 - n2v_mse: 0.0038 - n2v_abs: 0.0281 - val_loss: 0.0427 - val_n2v_mse: 0.0427 - val_n2v_abs: 0.0648
# Epoch 118/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0068 - n2v_mse: 0.0068 - n2v_abs: 0.0322 - val_loss: 0.0458 - val_n2v_mse: 0.0458 - val_n2v_abs: 0.0676
# Epoch 119/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0058 - n2v_mse: 0.0058 - n2v_abs: 0.0314 - val_loss: 0.0462 - val_n2v_mse: 0.0462 - val_n2v_abs: 0.0668
#
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 120/200
# 874/874 [==============================] - 69s 79ms/step - loss: 0.0065 - n2v_mse: 0.0065 - n2v_abs: 0.0321 - val_loss: 0.0511 - val_n2v_mse: 0.0511 - val_n2v_abs: 0.0713
# Epoch 121/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0067 - n2v_mse: 0.0067 - n2v_abs: 0.0302 - val_loss: 0.0396 - val_n2v_mse: 0.0396 - val_n2v_abs: 0.0617
# Epoch 122/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0061 - n2v_mse: 0.0061 - n2v_abs: 0.0321 - val_loss: 0.0657 - val_n2v_mse: 0.0657 - val_n2v_abs: 0.0804
# Epoch 123/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0060 - n2v_mse: 0.0060 - n2v_abs: 0.0317 - val_loss: 0.0410 - val_n2v_mse: 0.0410 - val_n2v_abs: 0.0646
# Epoch 124/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0058 - n2v_mse: 0.0058 - n2v_abs: 0.0310 - val_loss: 0.0364 - val_n2v_mse: 0.0364 - val_n2v_abs: 0.0602
# Epoch 125/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0100 - n2v_mse: 0.0100 - n2v_abs: 0.0344 - val_loss: 0.0494 - val_n2v_mse: 0.0494 - val_n2v_abs: 0.0692
# Epoch 126/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0053 - n2v_mse: 0.0053 - n2v_abs: 0.0308 - val_loss: 0.0567 - val_n2v_mse: 0.0567 - val_n2v_abs: 0.0758
# Epoch 127/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.0062 - n2v_mse: 0.0062 - n2v_abs: 0.0325 - val_loss: 0.0468 - val_n2v_mse: 0.0468 - val_n2v_abs: 0.0689
# Epoch 128/200
# 874/874 [==============================] - 74s 84ms/step - loss: 0.0052 - n2v_mse: 0.0052 - n2v_abs: 0.0307 - val_loss: 0.0448 - val_n2v_mse: 0.0448 - val_n2v_abs: 0.0671
# Epoch 129/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0045 - n2v_mse: 0.0045 - n2v_abs: 0.0298 - val_loss: 0.0433 - val_n2v_mse: 0.0433 - val_n2v_abs: 0.0661
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 130/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0050 - n2v_mse: 0.0050 - n2v_abs: 0.0295 - val_loss: 0.0439 - val_n2v_mse: 0.0439 - val_n2v_abs: 0.0655
# Epoch 131/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0074 - n2v_mse: 0.0074 - n2v_abs: 0.0330 - val_loss: 0.0422 - val_n2v_mse: 0.0422 - val_n2v_abs: 0.0644
# Epoch 132/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0048 - n2v_mse: 0.0048 - n2v_abs: 0.0296 - val_loss: 0.0642 - val_n2v_mse: 0.0642 - val_n2v_abs: 0.0787
# Epoch 133/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0053 - n2v_mse: 0.0053 - n2v_abs: 0.0316 - val_loss: 0.0534 - val_n2v_mse: 0.0534 - val_n2v_abs: 0.0710
# Epoch 134/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0056 - n2v_mse: 0.0056 - n2v_abs: 0.0307 - val_loss: 0.0481 - val_n2v_mse: 0.0481 - val_n2v_abs: 0.0694
# Epoch 135/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0062 - n2v_mse: 0.0062 - n2v_abs: 0.0317 - val_loss: 0.0451 - val_n2v_mse: 0.0451 - val_n2v_abs: 0.0670
# Epoch 136/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.0057 - n2v_mse: 0.0057 - n2v_abs: 0.0309 - val_loss: 0.0490 - val_n2v_mse: 0.0490 - val_n2v_abs: 0.0690
# Epoch 137/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0056 - n2v_mse: 0.0056 - n2v_abs: 0.0314 - val_loss: 0.0508 - val_n2v_mse: 0.0508 - val_n2v_abs: 0.0716
# Epoch 138/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0054 - n2v_mse: 0.0054 - n2v_abs: 0.0308 - val_loss: 0.0524 - val_n2v_mse: 0.0524 - val_n2v_abs: 0.0729
# Epoch 139/200
# 874/874 [==============================] - 74s 84ms/step - loss: 0.0071 - n2v_mse: 0.0071 - n2v_abs: 0.0308 - val_loss: 0.0545 - val_n2v_mse: 0.0545 - val_n2v_abs: 0.0726
#
# Epoch 00139: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 140/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0049 - n2v_mse: 0.0049 - n2v_abs: 0.0300 - val_loss: 0.0494 - val_n2v_mse: 0.0494 - val_n2v_abs: 0.0704
# Epoch 141/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0063 - n2v_mse: 0.0063 - n2v_abs: 0.0310 - val_loss: 0.0589 - val_n2v_mse: 0.0589 - val_n2v_abs: 0.0761
# Epoch 142/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0049 - n2v_mse: 0.0049 - n2v_abs: 0.0298 - val_loss: 0.0332 - val_n2v_mse: 0.0332 - val_n2v_abs: 0.0577
# Epoch 143/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0064 - n2v_mse: 0.0064 - n2v_abs: 0.0313 - val_loss: 0.0363 - val_n2v_mse: 0.0363 - val_n2v_abs: 0.0599
# Epoch 144/200
# 874/874 [==============================] - 74s 85ms/step - loss: 0.0049 - n2v_mse: 0.0049 - n2v_abs: 0.0304 - val_loss: 0.0381 - val_n2v_mse: 0.0381 - val_n2v_abs: 0.0630
# Epoch 145/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0065 - n2v_mse: 0.0065 - n2v_abs: 0.0309 - val_loss: 0.0572 - val_n2v_mse: 0.0572 - val_n2v_abs: 0.0757
# Epoch 146/200
# 874/874 [==============================] - 74s 84ms/step - loss: 0.0052 - n2v_mse: 0.0052 - n2v_abs: 0.0317 - val_loss: 0.0472 - val_n2v_mse: 0.0472 - val_n2v_abs: 0.0690
# Epoch 147/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0047 - n2v_mse: 0.0047 - n2v_abs: 0.0301 - val_loss: 0.0433 - val_n2v_mse: 0.0433 - val_n2v_abs: 0.0664
# Epoch 148/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0057 - n2v_mse: 0.0057 - n2v_abs: 0.0311 - val_loss: 0.0504 - val_n2v_mse: 0.0504 - val_n2v_abs: 0.0707
# Epoch 149/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0063 - n2v_mse: 0.0063 - n2v_abs: 0.0304 - val_loss: 0.0463 - val_n2v_mse: 0.0463 - val_n2v_abs: 0.0670
#
# Epoch 00149: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 150/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0058 - n2v_mse: 0.0058 - n2v_abs: 0.0315 - val_loss: 0.0345 - val_n2v_mse: 0.0345 - val_n2v_abs: 0.0599
# Epoch 151/200
# 874/874 [==============================] - 72s 82ms/step - loss: 0.0060 - n2v_mse: 0.0060 - n2v_abs: 0.0304 - val_loss: 0.0557 - val_n2v_mse: 0.0557 - val_n2v_abs: 0.0745
# Epoch 152/200
# 874/874 [==============================] - 73s 83ms/step - loss: 0.0077 - n2v_mse: 0.0077 - n2v_abs: 0.0337 - val_loss: 0.0529 - val_n2v_mse: 0.0529 - val_n2v_abs: 0.0717
# Epoch 153/200
# 874/874 [==============================] - 73s 84ms/step - loss: 0.0060 - n2v_mse: 0.0060 - n2v_abs: 0.0313 - val_loss: 0.0559 - val_n2v_mse: 0.0559 - val_n2v_abs: 0.0743
# Epoch 154/200
# 874/874 [==============================] - 72s 83ms/step - loss: 0.0059 - n2v_mse: 0.0059 - n2v_abs: 0.0331 - val_loss: 0.0529 - val_n2v_mse: 0.0529 - val_n2v_abs: 0.0706
# Epoch 155/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0055 - n2v_mse: 0.0055 - n2v_abs: 0.0307 - val_loss: 0.0482 - val_n2v_mse: 0.0482 - val_n2v_abs: 0.0681
# Epoch 156/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0055 - n2v_mse: 0.0055 - n2v_abs: 0.0317 - val_loss: 0.0322 - val_n2v_mse: 0.0322 - val_n2v_abs: 0.0584
# Epoch 157/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0047 - n2v_mse: 0.0047 - n2v_abs: 0.0295 - val_loss: 0.0408 - val_n2v_mse: 0.0408 - val_n2v_abs: 0.0634
# Epoch 158/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0047 - n2v_mse: 0.0047 - n2v_abs: 0.0304 - val_loss: 0.0508 - val_n2v_mse: 0.0508 - val_n2v_abs: 0.0712
# Epoch 159/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0050 - n2v_mse: 0.0050 - n2v_abs: 0.0311 - val_loss: 0.0539 - val_n2v_mse: 0.0539 - val_n2v_abs: 0.0738
#
# Epoch 00159: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 160/200
# 874/874 [==============================] - 69s 79ms/step - loss: 0.0051 - n2v_mse: 0.0051 - n2v_abs: 0.0311 - val_loss: 0.0366 - val_n2v_mse: 0.0366 - val_n2v_abs: 0.0606
# Epoch 161/200
# 874/874 [==============================] - 70s 81ms/step - loss: 0.0063 - n2v_mse: 0.0063 - n2v_abs: 0.0306 - val_loss: 0.0423 - val_n2v_mse: 0.0423 - val_n2v_abs: 0.0649
# Epoch 162/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0057 - n2v_mse: 0.0057 - n2v_abs: 0.0304 - val_loss: 0.0525 - val_n2v_mse: 0.0525 - val_n2v_abs: 0.0722
# Epoch 163/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0044 - n2v_mse: 0.0044 - n2v_abs: 0.0297 - val_loss: 0.0424 - val_n2v_mse: 0.0424 - val_n2v_abs: 0.0641
# Epoch 164/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0061 - n2v_mse: 0.0061 - n2v_abs: 0.0310 - val_loss: 0.0487 - val_n2v_mse: 0.0487 - val_n2v_abs: 0.0692
# Epoch 165/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0036 - n2v_mse: 0.0036 - n2v_abs: 0.0284 - val_loss: 0.0388 - val_n2v_mse: 0.0388 - val_n2v_abs: 0.0613
# Epoch 166/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0052 - n2v_mse: 0.0052 - n2v_abs: 0.0314 - val_loss: 0.0388 - val_n2v_mse: 0.0388 - val_n2v_abs: 0.0616
# Epoch 167/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0059 - n2v_mse: 0.0059 - n2v_abs: 0.0310 - val_loss: 0.0482 - val_n2v_mse: 0.0482 - val_n2v_abs: 0.0696
# Epoch 168/200
# 874/874 [==============================] - 70s 81ms/step - loss: 0.0070 - n2v_mse: 0.0070 - n2v_abs: 0.0326 - val_loss: 0.0451 - val_n2v_mse: 0.0451 - val_n2v_abs: 0.0665
# Epoch 169/200
# 874/874 [==============================] - 69s 79ms/step - loss: 0.0075 - n2v_mse: 0.0075 - n2v_abs: 0.0323 - val_loss: 0.0318 - val_n2v_mse: 0.0318 - val_n2v_abs: 0.0569
#
# Epoch 00169: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# Epoch 170/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0075 - n2v_mse: 0.0075 - n2v_abs: 0.0322 - val_loss: 0.0407 - val_n2v_mse: 0.0407 - val_n2v_abs: 0.0638
# Epoch 171/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0062 - n2v_mse: 0.0062 - n2v_abs: 0.0312 - val_loss: 0.0479 - val_n2v_mse: 0.0479 - val_n2v_abs: 0.0690
# Epoch 172/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0060 - n2v_mse: 0.0060 - n2v_abs: 0.0310 - val_loss: 0.0462 - val_n2v_mse: 0.0462 - val_n2v_abs: 0.0677
# Epoch 173/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0064 - n2v_mse: 0.0064 - n2v_abs: 0.0323 - val_loss: 0.0672 - val_n2v_mse: 0.0672 - val_n2v_abs: 0.0819
# Epoch 174/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0054 - n2v_mse: 0.0054 - n2v_abs: 0.0300 - val_loss: 0.0478 - val_n2v_mse: 0.0478 - val_n2v_abs: 0.0697
# Epoch 175/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0070 - n2v_mse: 0.0070 - n2v_abs: 0.0317 - val_loss: 0.0453 - val_n2v_mse: 0.0453 - val_n2v_abs: 0.0656
# Epoch 176/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0052 - n2v_mse: 0.0052 - n2v_abs: 0.0303 - val_loss: 0.0443 - val_n2v_mse: 0.0443 - val_n2v_abs: 0.0656
# Epoch 177/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0069 - n2v_mse: 0.0069 - n2v_abs: 0.0307 - val_loss: 0.0451 - val_n2v_mse: 0.0451 - val_n2v_abs: 0.0674
# Epoch 178/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0057 - n2v_mse: 0.0057 - n2v_abs: 0.0306 - val_loss: 0.0521 - val_n2v_mse: 0.0521 - val_n2v_abs: 0.0727
# Epoch 179/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0046 - n2v_mse: 0.0046 - n2v_abs: 0.0306 - val_loss: 0.0502 - val_n2v_mse: 0.0502 - val_n2v_abs: 0.0696
#
# Epoch 00179: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
# Epoch 180/200
# 874/874 [==============================] - 69s 79ms/step - loss: 0.0053 - n2v_mse: 0.0053 - n2v_abs: 0.0301 - val_loss: 0.0472 - val_n2v_mse: 0.0472 - val_n2v_abs: 0.0683
# Epoch 181/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0052 - n2v_mse: 0.0052 - n2v_abs: 0.0303 - val_loss: 0.0470 - val_n2v_mse: 0.0470 - val_n2v_abs: 0.0689
# Epoch 182/200
# 874/874 [==============================] - 69s 79ms/step - loss: 0.0050 - n2v_mse: 0.0050 - n2v_abs: 0.0302 - val_loss: 0.0630 - val_n2v_mse: 0.0630 - val_n2v_abs: 0.0787
# Epoch 183/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0057 - n2v_mse: 0.0057 - n2v_abs: 0.0296 - val_loss: 0.0620 - val_n2v_mse: 0.0620 - val_n2v_abs: 0.0793
# Epoch 184/200
# 874/874 [==============================] - 69s 79ms/step - loss: 0.0046 - n2v_mse: 0.0046 - n2v_abs: 0.0306 - val_loss: 0.0479 - val_n2v_mse: 0.0479 - val_n2v_abs: 0.0696
# Epoch 185/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0054 - n2v_mse: 0.0054 - n2v_abs: 0.0303 - val_loss: 0.0469 - val_n2v_mse: 0.0469 - val_n2v_abs: 0.0691
# Epoch 186/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0043 - n2v_mse: 0.0043 - n2v_abs: 0.0298 - val_loss: 0.0525 - val_n2v_mse: 0.0525 - val_n2v_abs: 0.0709
# Epoch 187/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0053 - n2v_mse: 0.0053 - n2v_abs: 0.0308 - val_loss: 0.0322 - val_n2v_mse: 0.0322 - val_n2v_abs: 0.0569
# Epoch 188/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0058 - n2v_mse: 0.0058 - n2v_abs: 0.0303 - val_loss: 0.0542 - val_n2v_mse: 0.0542 - val_n2v_abs: 0.0744
# Epoch 189/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0050 - n2v_mse: 0.0050 - n2v_abs: 0.0293 - val_loss: 0.0447 - val_n2v_mse: 0.0447 - val_n2v_abs: 0.0665
#
# Epoch 00189: ReduceLROnPlateau reducing learning rate to 6.103515470812226e-09.
# Epoch 190/200
# 874/874 [==============================] - 70s 81ms/step - loss: 0.0046 - n2v_mse: 0.0046 - n2v_abs: 0.0306 - val_loss: 0.0447 - val_n2v_mse: 0.0447 - val_n2v_abs: 0.0677
# Epoch 191/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0046 - n2v_mse: 0.0046 - n2v_abs: 0.0291 - val_loss: 0.0539 - val_n2v_mse: 0.0539 - val_n2v_abs: 0.0728
# Epoch 192/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0053 - n2v_mse: 0.0053 - n2v_abs: 0.0299 - val_loss: 0.0360 - val_n2v_mse: 0.0360 - val_n2v_abs: 0.0606
# Epoch 193/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0055 - n2v_mse: 0.0055 - n2v_abs: 0.0313 - val_loss: 0.0475 - val_n2v_mse: 0.0475 - val_n2v_abs: 0.0697
# Epoch 194/200
# 874/874 [==============================] - 71s 81ms/step - loss: 0.0061 - n2v_mse: 0.0061 - n2v_abs: 0.0325 - val_loss: 0.0504 - val_n2v_mse: 0.0504 - val_n2v_abs: 0.0705
# Epoch 195/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0059 - n2v_mse: 0.0059 - n2v_abs: 0.0325 - val_loss: 0.0513 - val_n2v_mse: 0.0513 - val_n2v_abs: 0.0706
# Epoch 196/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0047 - n2v_mse: 0.0047 - n2v_abs: 0.0294 - val_loss: 0.0403 - val_n2v_mse: 0.0403 - val_n2v_abs: 0.0637
# Epoch 197/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0065 - n2v_mse: 0.0065 - n2v_abs: 0.0317 - val_loss: 0.0565 - val_n2v_mse: 0.0565 - val_n2v_abs: 0.0760
# Epoch 198/200
# 874/874 [==============================] - 71s 82ms/step - loss: 0.0050 - n2v_mse: 0.0050 - n2v_abs: 0.0303 - val_loss: 0.0473 - val_n2v_mse: 0.0473 - val_n2v_abs: 0.0687
# Epoch 199/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0041 - n2v_mse: 0.0041 - n2v_abs: 0.0288 - val_loss: 0.0408 - val_n2v_mse: 0.0408 - val_n2v_abs: 0.0638
#
# Epoch 00199: ReduceLROnPlateau reducing learning rate to 3.051757735406113e-09.
# Epoch 200/200
# 874/874 [==============================] - 70s 80ms/step - loss: 0.0059 - n2v_mse: 0.0059 - n2v_abs: 0.0311 - val_loss: 0.0495 - val_n2v_mse: 0.0495 - val_n2v_abs: 0.0689
#
# Loading network weights from 'weights_best.h5'.

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss']);
# Out:
# ['loss', 'lr', 'n2v_abs', 'n2v_mse', 'val_loss', 'val_n2v_abs', 'val_n2v_mse']

# %%
model.export_TF(name='Noise2Void: PIV denoising', 
                description='N2V trained in python on exp 317 dataset PIV.', 
                authors=["Jesse Holt"],
                test_img=X_val[0,...,0], axes='ZYX',
                patch_shape=patch_shape)
# Out:
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: C:\Users\17605\AppData\Local\Temp\tmp9m9jfcun\model\saved_model.pb
#
# Model exported in BioImage ModelZoo format:
# C:\Users\17605\Code\n2v\examples\3D\models\2022_04_21_n2v_317cko\export.bioimage.io.zip

# %%
# Previously trained model is loaded by creating a new N2V-object without providing a 'config'.
model = N2V(config=None, name=model_name, basedir=basedir)
# Out:
# Loading network weights from 'weights_best.h5'.

# %%
# We load the data we want to process.
img = imread( "F:/Jesse/cKO/317_2021_03_27_mkera_batch66_ScratchFast/n2v/C1-317_2021_03_27_mkera_batch66_ScratchFast_1_MMStack_Pos0-Skin4.ome.tif")

# Here we process the data.
# The 'n_tiles' parameter can be used if images are too big for the GPU memory.
# If we do not provide the 'n_tiles' parameter the system will automatically try to find an appropriate tiling.
pred = model.predict(img, axes='ZYX', n_tiles=(2,4,4))
# Out:
# The input image is of type uint16 and will be casted to float32 for prediction.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 32/32 [00:42<00:00,  1.33s/it]

# %%
# Let's look at the results.
plt.figure(figsize=(30,30))

# We show the noisy input...
plt.subplot(1,2,1)
plt.imshow(np.max(img,axis=0),
           cmap='magma',
           vmin=np.percentile(img,0.1),
           vmax=np.percentile(img,99.9)
          )
plt.title('Input');

# and the result.
plt.subplot(1,2,2)
plt.imshow(np.max(pred,axis=0), 
           cmap='magma',
           vmin=np.percentile(pred,0.1),
           vmax=np.percentile(pred,99.9)
          )
plt.title('Prediction');

# %%
save_tiff_imagej_compatible('prediction_noclahe.tif', pred, 'ZYX')

# %%
from datetime import datetime

ErrorFiles=[]
datagen = N2V_DataGenerator()
folder = "F:/Jesse/cKO/cKO_PIV_less/Nuclei/317/"
imgs = datagen.load_imgs_from_directory(directory = folder, filter = '*.tif', dims='ZYX')
patch_shape = (16, 16, 16)
date = datetime.now().strftime("%Y_%m_%d_")
img_list =  sorted(glob.glob(os.path.join(folder, "*.tif")))

for i in range(len(imgs)):
    try:
        # Here we extract patches for training and validation.
        patches = datagen.generate_patches_from_list(imgs[i:i+1], shape=patch_shape)
        X = patches[:int(len(patches)-(len(patches)/10)),:]
        X_val = patches[int(len(patches)-(len(patches)/10)):,:]
        
        
        sfx = img_list[i].split('\\')
        file_name = sfx[-1][:-4] 
        
        config = N2VConfig(X, unet_kern_size=3, 
                   train_steps_per_epoch=int(X.shape[0]/128),train_epochs=200, train_loss='mse', batch_norm=True, 
                   train_batch_size=30, n2v_perc_pix=0.198, n2v_patch_shape = patch_shape, 
                   n2v_manipulator='uniform_withCP', n2v_neighborhood_radius=5)

        # a name used to identify the model
        model_name = f'{date}{file_name}'
        # the base directory in which our model will live
        basedir = 'models'
        # We are now creating our network model.
        model = N2V(config=config, name=model_name, basedir=basedir)
        
        history = model.train(X, X_val)
        
        model.export_TF(name=f'Noise2Void: PIV denoising of {file_name}', 
                description='N2V trained in python on exp 317 dataset PIV.', 
                authors=["Jesse Holt"],
                test_img=X_val[0,...,0], axes='ZYX',
                patch_shape=patch_shape)

        print(sorted(list(history.history.keys())))
        plt.figure(figsize=(16,5))
        plot_history(history,['loss','val_loss']);
        
        model = N2V(config=None, name=model_name, basedir=basedir)
        
        img = imread(img_list[i])
        
        pred = model.predict(img, axes='ZYX', n_tiles=(2,4,4))
        
        save_tiff_imagej_compatible(f'{file_name}_prediction.tif', pred, 'ZYX')

    except:
        sfx = img_list[i].split('\\')
        file_name = sfx[-1][:-4] 
        ErrorFiles.append(file_name)
        pass
# Out:
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# Generated patches: (58752, 16, 16, 16, 1)
# 8 blind-spots will be generated per training patch of size (16, 16, 16).
# Preparing validation data: 100%|████████████████████████████████████████████████| 5876/5876 [00:00<00:00, 12347.05it/s]
# Epoch 1/200
# 413/413 [==============================] - 31s 69ms/step - loss: 0.2929 - n2v_mse: 0.2929 - n2v_abs: 0.2569 - val_loss: 0.2281 - val_n2v_mse: 0.2277 - val_n2v_abs: 0.2162
# Epoch 2/200
# 413/413 [==============================] - 27s 66ms/step - loss: 0.1674 - n2v_mse: 0.1674 - n2v_abs: 0.2069 - val_loss: 0.1210 - val_n2v_mse: 0.1208 - val_n2v_abs: 0.1767
# Epoch 3/200
# 413/413 [==============================] - 28s 67ms/step - loss: 0.1461 - n2v_mse: 0.1461 - n2v_abs: 0.1984 - val_loss: 0.1507 - val_n2v_mse: 0.1506 - val_n2v_abs: 0.2659
# Epoch 4/200
# 413/413 [==============================] - 27s 67ms/step - loss: 0.2272 - n2v_mse: 0.2272 - n2v_abs: 0.2267 - val_loss: 0.2355 - val_n2v_mse: 0.2351 - val_n2v_abs: 0.2128
# Epoch 5/200
#  97/413 [======>.......................] - ETA: 18s - loss: 0.1092 - n2v_mse: 0.1092 - n2v_abs: 0.1880

# %%
ErrorFiles
